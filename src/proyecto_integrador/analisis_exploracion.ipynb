# %%
# !pip install streamlit
# Out:
# Requirement already satisfied: streamlit in /usr/local/python/3.12.1/lib/python3.12/site-packages (1.51.0)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<6,>=4.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from streamlit) (6.2.2)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from streamlit) (8.3.1)
# Requirement already satisfied: numpy<3,>=1.23 in /home/codespace/.local/lib/python3.12/site-packages (from streamlit) (2.3.5)
# Requirement already satisfied: packaging<26,>=20 in /home/codespace/.local/lib/python3.12/site-packages (from streamlit) (25.0)
# Requirement already satisfied: pandas<3,>=1.4.0 in /home/codespace/.local/lib/python3.12/site-packages (from streamlit) (2.3.3)
# Requirement already satisfied: pillow<13,>=7.1.0 in /home/codespace/.local/lib/python3.12/site-packages (from streamlit) (12.0.0)
# Requirement already satisfied: protobuf<7,>=3.20 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from streamlit) (6.33.1)
# Requirement already satisfied: pyarrow<22,>=7.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from streamlit) (21.0.0)
# Requirement already satisfied: requests<3,>=2.27 in /home/codespace/.local/lib/python3.12/site-packages (from streamlit) (2.32.5)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from streamlit) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in /home/codespace/.local/lib/python3.12/site-packages (from streamlit) (4.15.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /home/codespace/.local/lib/python3.12/site-packages (from streamlit) (3.1.45)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in /home/codespace/.local/lib/python3.12/site-packages (from streamlit) (6.5.2)
# Requirement already satisfied: jinja2 in /home/codespace/.local/lib/python3.12/site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /home/codespace/.local/lib/python3.12/site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (4.25.1)
# Requirement already satisfied: narwhals>=1.14.2 in /home/codespace/.local/lib/python3.12/site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2.10.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/codespace/.local/lib/python3.12/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/codespace/.local/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/codespace/.local/lib/python3.12/site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/codespace/.local/lib/python3.12/site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/codespace/.local/lib/python3.12/site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/codespace/.local/lib/python3.12/site-packages (from requests<3,>=2.27->streamlit) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.12/site-packages (from requests<3,>=2.27->streamlit) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/codespace/.local/lib/python3.12/site-packages (from requests<3,>=2.27->streamlit) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.12/site-packages (from requests<3,>=2.27->streamlit) (2025.10.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/codespace/.local/lib/python3.12/site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in /home/codespace/.local/lib/python3.12/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/codespace/.local/lib/python3.12/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/codespace/.local/lib/python3.12/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/codespace/.local/lib/python3.12/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.28.0)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)

# %%
from ingestar import Ingestar
from reporte import Reporte
import streamlit as st

# %%
kaggle = "jlgrego/apartamentos-venda-na-cidade-de-sao-paulo-sp"
ingestar = Ingestar()

# %%
archivo = ingestar.download_dataset_zip(kaggle)
zip_kaggle = ingestar.extract_zip_files(archivo)
df = ingestar.load_dataset_as_dataframe(zip_kaggle)
# Out:
# Descargando dataset desde Kaggle...
# Ruta al dataset: /home/codespace/.cache/kagglehub/datasets/jlgrego/apartamentos-venda-na-cidade-de-sao-paulo-sp/versions/1
# Archivos encontrados en la descarga: ['dados_wgs.xlsx']
# Se detectaron archivos XLSX directamente en la carpeta descargada.
# Leyendo Excel /home/codespace/.cache/kagglehub/datasets/jlgrego/apartamentos-venda-na-cidade-de-sao-paulo-sp/versions/1/dados_wgs.xlsx ...
# ✅ Dataset cargado correctamente en DataFrame.

# %%
df.head(2)
# Out:
#     id  valor_total     unit  area_util  quartos  vagas  condominio  suites  \
# 0  526       189900  5934.38         32        2      1       180.0       0
# 1  734       221110  5142.09         43        2      1       250.0       0
#
#    banheiros  piscina  ...  qtd_dados_bairro  media_idh media_gini  \
# 0          1        0  ...              36.0   0.697182   0.410909
# 1          1        0  ...              36.0   0.697182   0.410909
#
#   expectativa_vida renda_percapita          estacao_prox  linha_prox  \
# 0        72.751818      559.668182            SÃO MATEUS       PRATA
# 1        72.751818      559.668182  CORINTHIANS-ITAQUERA    VERMELHA
#
#           dist        lat        lon
# 0  6822.823684 -23.583879 -46.417548
# 1  4682.709841 -23.543535 -46.425492
#
# [2 rows x 26 columns]

# %%
st.set_page_config(page_title="Dashboard Inmobiliario", layout="wide")
dashboard = Reporte(df)
dashboard.render()
# Out:
# 2025-11-27 21:14:07.617 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 21:14:07.618 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 21:14:07.645
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /home/codespace/.local/lib/python3.12/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2025-11-27 21:14:07.645 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 21:14:07.646 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 21:14:07.647 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 21:14:07.648 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 21:14:07.648 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 21:14:07.653 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 21:14:07.653 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 21:14:07.654 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 21:14:07.655 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 21:14:07.655 Session state does not function when running a script without `streamlit run`
# 2025-11-27 21:14:07.656 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 21:14:07.657 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 21:14:07.658 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 21:14:07.658 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 21:14:07.659 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 21:14:07.660 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 21:14:07.661 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 21:14:07.661 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 21:14:07.662 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 21:14:07.663 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 21:14:07.664 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 21:14:07.664 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 21:14:07.665 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 21:14:07.665 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 21:14:07.666 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 21:14:07.667 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 21:14:07.669 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 21:14:07.670 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 21:14:07.670 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 21:14:07.671 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 21:14:07.671 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 21:14:07.672 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 21:14:07.672 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 21:14:07.673 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 21:14:07.674 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 21:14:07.675 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 21:14:07.676 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 21:14:07.676 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 21:14:07.677 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 21:14:07.678 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 21:14:07.679 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 21:14:07.679 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 21:14:07.680 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 21:14:07.680 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 21:14:07.681 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 21:14:07.682 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 21:14:07.683 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 21:14:07.683 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 21:14:07.684 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 21:14:07.685 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 21:14:07.685 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[22], line 3
#       1 st.set_page_config(page_title="Dashboard Inmobiliario", layout="wide")
#       2 dashboard = Reporte(df)
# ----> 3 dashboard.render()
#
# File /workspaces/piv_2025_2_2/src/proyecto_integrador/reporte.py:109, in Reporte.render(self)
#     106     self.render_filters()
#     108 # Secciones principales
# --> 109 self.render_kpis()
#     110 self.render_exploratory_charts()
#
# File /workspaces/piv_2025_2_2/src/proyecto_integrador/reporte.py:50, in Reporte.render_kpis(self)
#      46 st.markdown("### Comparación de indicadores")
#      47 kpi_df = pd.DataFrame(
#      48     {"Indicador": list(kpis.keys()), "Valor": list(kpis.values())}
#      49 )
# ---> 50 st.bar_chart(kpi_df.set_index("Indicador"))
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/streamlit/runtime/metrics_util.py:447, in gather_metrics.<locals>.wrapped_func(*args, **kwargs)
#     445         _LOGGER.debug("Failed to collect command telemetry", exc_info=ex)
#     446 try:
# --> 447     result = non_optional_func(*args, **kwargs)
#     448 except RerunException:
#     449     # Duplicated from below, because static analysis tools get confused
#     450     # by deferring the rethrow.
#     451     if tracking_activated and command_telemetry:
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/streamlit/elements/vega_charts.py:1448, in VegaChartsMixin.bar_chart(self, data, x, y, x_label, y_label, color, horizontal, sort, stack, width, height, use_container_width)
#    1426 bar_chart_type = (
#    1427     ChartType.HORIZONTAL_BAR if horizontal else ChartType.VERTICAL_BAR
#    1428 )
#    1430 chart, add_rows_metadata = generate_chart(
#    1431     chart_type=bar_chart_type,
#    1432     data=data,
#    (...)   1444     sort_from_user=sort,
#    1445 )
#    1446 return cast(
#    1447     "DeltaGenerator",
# -> 1448     self._altair_chart(
#    1449         chart,
#    1450         use_container_width=use_container_width,
#    1451         theme="streamlit",
#    1452         add_rows_metadata=add_rows_metadata,
#    1453         width=width,
#    1454         height=height,
#    1455     ),
#    1456 )
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/streamlit/elements/vega_charts.py:2171, in VegaChartsMixin._altair_chart(self, altair_chart, use_container_width, theme, key, on_select, selection_mode, add_rows_metadata, width, height)
#    2163 if type_util.is_altair_version_less_than("5.0.0") and on_select != "ignore":
#    2164     raise StreamlitAPIException(
#    2165         "Streamlit does not support selections with Altair 4.x. Please upgrade "
#    2166         "to Version 5. "
#    2167         "If you would like to use Altair 4.x with selections, please upvote "
#    2168         "this [Github issue](https://github.com/streamlit/streamlit/issues/8516)."
#    2169     )
# -> 2171 vega_lite_spec = _convert_altair_to_vega_lite_spec(altair_chart)
#    2172 return self._vega_lite_chart(
#    2173     data=None,  # The data is already part of the spec
#    2174     spec=vega_lite_spec,
#    (...)   2182     height=height,
#    2183 )
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/streamlit/elements/vega_charts.py:419, in _convert_altair_to_vega_lite_spec(altair_chart)
#     416     with theme_context:  # ty: ignore[invalid-context-manager]
#     417         # type: ignore[attr-defined,unused-ignore]
#     418         with data_transformer:  # ty: ignore[invalid-context-manager]
# --> 419             chart_dict = altair_chart.to_dict()
#     421 # Put datasets back into the chart dict:
#     422 chart_dict["datasets"] = datasets
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/altair/vegalite/v5/api.py:4033, in Chart.to_dict(self, validate, format, ignore, context)
#    4031     copy.data = core.InlineData(values=[{}])
#    4032     return super(Chart, copy).to_dict(**kwds)
# -> 4033 return super().to_dict(**kwds)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/altair/vegalite/v5/api.py:1998, in TopLevelMixin.to_dict(self, validate, format, ignore, context)
#    1995     except TypeError:
#    1996         # Non-narwhalifiable type supported by Altair, such as dict
#    1997         data = original_data
# -> 1998     copy.data = _prepare_data(data, context)
#    1999     context["data"] = data
#    2001 # remaining to_dict calls are not at top level
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/altair/vegalite/v5/api.py:283, in _prepare_data(data, context)
#     281 elif not isinstance(data, dict) and _is_data_type(data):
#     282     if func := data_transformers.get():
# --> 283         data = func(nw.to_native(data, pass_through=True))
#     285 # convert string input to a URLData
#     286 elif isinstance(data, str):
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/streamlit/elements/vega_charts.py:2375, in _to_arrow_dataset(data, datasets)
#    2368 """Altair data transformer that serializes the data,
#    2369 creates a stable name based on the hash of the data,
#    2370 stores the bytes into the datasets mapping and
#    2371 returns this name to have it be used in Altair.
#    2372 """
#    2373 # Already serialize the data to be able to create a stable
#    2374 # dataset name:
# -> 2375 data_bytes = dataframe_util.convert_anything_to_arrow_bytes(data)
#    2376 # Use the md5 hash of the data as the name:
#    2377 name = calc_md5(str(data_bytes))
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/streamlit/dataframe_util.py:909, in convert_anything_to_arrow_bytes(data, max_unevaluated_rows)
#     904 # TODO(lukasmasuch): Add direct conversion to Arrow for supported formats here
#     905
#     906 # Fallback: try to convert to pandas DataFrame
#     907 # and then to Arrow bytes.
#     908 df = convert_anything_to_pandas_df(data, max_unevaluated_rows)
# --> 909 return convert_pandas_df_to_arrow_bytes(df)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/streamlit/dataframe_util.py:829, in convert_pandas_df_to_arrow_bytes(df)
#     826 import pyarrow as pa
#     828 try:
# --> 829     table = pa.Table.from_pandas(df)
#     830 except (pa.ArrowTypeError, pa.ArrowInvalid, pa.ArrowNotImplementedError) as ex:
#     831     _LOGGER.info(
#     832         "Serialization of dataframe to Arrow table was unsuccessful. "
#     833         "Applying automatic fixes for column types to make the dataframe "
#     834         "Arrow-compatible.",
#     835         exc_info=ex,
#     836     )
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pyarrow/table.pxi:4794, in pyarrow.lib.Table.from_pandas()
#
# ModuleNotFoundError: No module named 'pyarrow.pandas_compat'
